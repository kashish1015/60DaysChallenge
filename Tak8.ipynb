# %%
# !pip install nltk

# %%
import nltk
import re
import string

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
social_media = """
OMG!!! 😂😂 This movie was sooo good!!!! I can't stop watching it 😍🔥 #Amazing
"""

news_article = """
Breaking News: The government announced new policies today. Experts say the economy may improve significantly in 2025.
"""

customer_review = """
I ordered this product last week... honestly, it was terrible :( The packaging was damaged and delivery was late!!!
"""

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

for name, text in samples.items():

    words = word_tokenize(text.lower())

    filtered_words = [
        word for word in words
        if word.isalnum() and word not in stop_words
    ]

    print("=" * 50)
    print(name)
    print("=" * 50)

    print("Before Removal:", len(words))
    print("After Removal:", len(filtered_words))

    print("\nFiltered Words:")
    print(filtered_words)

    print()
# Out:
# ...
# Social Media
# ...
# Before Removal: 23
# After Removal: 8
#
# Filtered Words:
# ['omg', 'movie', 'sooo', 'good', 'ca', 'stop', 'watching', 'amazing']
#
# ...
# News Article
# ...
# Before Removal: 20
# After Removal: 14
#
# Filtered Words:
# ['breaking', 'news', 'government', 'announced', 'new', 'policies', 'today', 'experts', 'say', 'economy', 'may', 'improve', 'significantly', '2025']
#
# ...
# Customer Review
# ...
# Before Removal: 25
# After Removal: 10
#
# Filtered Words:
# ['ordered', 'product', 'last', 'week', 'honestly', 'terrible', 'packaging', 'damaged', 'delivery', 'late']

# %%
for name, text in samples.items():

    # Remove punctuation using regex
    cleaned_text = re.sub(r'[^\w\s]', '', text)

    print("=" * 50)
    print(name)
    print("=" * 50)

    print("Before Cleaning:")
    print(text)

    print("\nAfter Cleaning:")
    print(cleaned_text)

    print()
# Out:
# ...
# Social Media
# ...
# Before Cleaning:
#
# OMG!!! 😂😂 This movie was sooo good!!!! I can't stop watching it 😍🔥 #Amazing
#
#
# After Cleaning:
#
# OMG  This movie was sooo good I cant stop watching it  Amazing
#
#
# ...
# News Article
# ...
# Before Cleaning:
#
# Breaking News: The government announced new policies today. Experts say the economy may improve significantly in 2025.
#
#
# After Cleaning:
#
# Breaking News The government announced new policies today Experts say the economy may improve significantly in 2025
#
#
# ...
# Customer Review
# ...
# Before Cleaning:
#
# I ordered this product last week... honestly, it was terrible :( The packaging was damaged and delivery was late!!!
#
#
# After Cleaning:
#
# I ordered this product last week honestly it was terrible  The packaging was damaged and delivery was late

# %%
stemmer = PorterStemmer()

sample_words = ["running", "studies", "playing", "easily", "better"]

for word in sample_words:
    print(word, "→", stemmer.stem(word))
# Out:
# running → run
# studies → studi
# playing → play
# easily → easili
# better → better

# %%
lemmatizer = WordNetLemmatizer()

sample_words = ["running", "studies", "playing", "easily", "better"]

for word in sample_words:
    print(word, "→", lemmatizer.lemmatize(word))
# Out:
# running → running
# studies → study
# playing → playing
# easily → easily
# better → better

# %%
words = ["running", "studies", "playing", "easily", "better"]

print("{:<15} {:<15} {:<15}".format("Original", "Stemmed", "Lemmatized"))

for word in words:
    stemmed = stemmer.stem(word)
    lemmatized = lemmatizer.lemmatize(word)

    print("{:<15} {:<15} {:<15}".format(
        word,
        stemmed,
        lemmatized
    ))
# Out:
# Original        Stemmed         Lemmatized
# running         run             running
# studies         studi           study
# playing         play            playing
# easily          easili          easily
# better          better          better
